# %%
import pandas as pd

# %%
foodname = pd.read_csv("data/foodname_FI.csv", usecols=['FOODID', 'FOODNAME', 'LANG'])
component = pd.read_csv("data/component_value.csv", usecols=['FOODID', 'EUFDNAME', 'BESTLOC'])
eufdname = pd.read_csv("data/eufdname_FI.csv", usecols=['THSCODE', 'DESCRIPT'])
df = pd.DataFrame()

# %%
print(component_df.head())
print(foodname.head())
print(eufdname.head())
# Out:
#    FOODID EUFDNAME  BESTLOC
# 0       1    ENERC   1698.0
# 1       1      FAT      0.0
# 2       1   CHOAVL     99.0
# 3       1     PROT      0.0
# 4       1      ALC      0.0
#    FOODID   FOODNAME            LANG
# 0       1     SOKERI              FI
# 1       2  FRUKTOOSI   HEDELM�SOKERI
# 2       3   SIIRAPPI              FI
# 3       4     HUNAJA              FI
# 4       5   MAKEINEN       KARAMELLI
#   THSCODE                   DESCRIPT
# 0   ENERC                    energia
# 1  XENERC                    energia
# 2     FAT                      rasva
# 3  CHOAVL    hiilihydraatti imeytyv�
# 4  CHOCDF  hiilihydraatti erotuksena

# %%
df = component.groupby('EUFDNAME')
df.first()
# Out:
#           FOODID  BESTLOC
# EUFDNAME
# ALC            1      0.0
# CA             1      0.0
# CAROTENS       1      0.0
# CHOAVL         1     99.0
# CHOLE          1      0.0
# ENERC          1   1698.0
# F18D2CN6       1      0.0
# F18D3N3        1      0.0
# F20D5N3        1      0.0
# F22D6N3        1      0.0
# FAFRE          1      0.0
# FAMCIS         1      0.0
# FAPU           1      0.0
# FAPUN3         1      0.0
# FAPUN6         1      0.0
# FASAT          1      0.0
# FAT            1      0.0
# FATRN          1      0.0
# FE             1      0.0
# FIBC           1      0.0
# FIBINS         1      0.0
# FOL            1      0.0
# FRUS           1      0.0
# GALS           1      0.0
# GLUS           1      0.0
# ID             1      5.0
# K              1      2.0
# LACS           1      0.0
# MALS           1      0.0
# MG             1      0.0
# NACL           1      0.0
# NIA            1      0.0
# NIAEQ          1      0.0
# OA             1      0.0
# ...

# %% [markdown]
# PROFIILI -> Valitaan FOODID(foodname) -for-loop> EUFDNAME, BESTLOC
# PROFIILI: ENERGIA 33( kcal(BESTLOC)

# %%
a = [{'id':123, 'name': 'AAA'}, {'id':456, 'name': 'BBB'}, {'id':789, 'name': 'TTT'}]
df1 = pd.DataFrame(a)
b = [{'id':123}]
df2 = pd.DataFrame(b)

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_19072/4218043754.py in <module>
# ----> 1 df2['name'] = df2['id'].map(df1.set_index('id')['name'])
#       2 df2
#
# ~/anaconda3/envs/algoritmit/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# ~/anaconda3/envs/algoritmit/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     840             values = self._values
#     841
# --> 842             indexer = mapper.index.get_indexer(values)
#     843             new_values = algorithms.take_nd(mapper._values, indexer)
#     844
#
# ...

# %%
df['wut'] = foodname['FOODID'].map(component.set_index('FOODID')['EUFDNAME'])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# /tmp/ipykernel_19072/2551616051.py in <module>
# ----> 1 df['wut'] = foodname['FOODID'].map(component.set_index('FOODID')['EUFDNAME'])
#
# ~/anaconda3/envs/algoritmit/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# ~/anaconda3/envs/algoritmit/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     840             values = self._values
#     841
# --> 842             indexer = mapper.index.get_indexer(values)
#     843             new_values = algorithms.take_nd(mapper._values, indexer)
#     844
#
# ...
